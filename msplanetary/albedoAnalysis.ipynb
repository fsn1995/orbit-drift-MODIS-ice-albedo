# %%
import odc.stac
import planetary_computer
import shapely.geometry
import pystac_client
import rich.table
import geopandas
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
catalog = pystac_client.Client.open(
    "https://planetarycomputer.microsoft.com/api/stac/v1",
    modifier=planetary_computer.sign_inplace,
)

# %%
# # poi in GrIS - KAN_M
# location = shapely.geometry.Point(-48.8355, 67.0670)
location = geopandas.read_file("asset/GrISiceMask.shp")
# location = shapely.geometry.LineString([(-180, 66.5), (180, 66.5)])
# bbox = location.buffer(2).bounds
time_range = "2000-03-01/2001-12-31"
items = dict()

search = catalog.search(
    collections=["modis-10A1-061"],
    intersects=location,
    datetime=time_range
    )
    
items = search.get_all_items()
len(items)
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# Cell In [4], line 15
#       7 items = dict()
#       9 search = catalog.search(
#      10     collections=["modis-10A1-061"],
#      11     intersects=location,
#      12     datetime=time_range
#      13     )
# ---> 15 items = search.get_all_items()
#      16 len(items)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pystac_client/item_search.py:805, in ItemSearch.get_all_items(self)
#     793 """DEPRECATED
#     794
#     795 .. deprecated:: 0.4.0
#    (...)
#     799     item_collection : ItemCollection
#     800 """
#     801 warnings.warn(
#     802     "get_all_items() is deprecated, use item_collection() instead.",
#     803     DeprecationWarning,
#     804 )
# --> 805 return self.item_collection()
#
# ...

# %%
df = geopandas.GeoDataFrame.from_features(items.to_dict(), crs="epsg:4326")
df["date"] = pd.to_datetime(df.start_datetime)
df.head()
# Out:
#                                             geometry               created  \
# 0  POLYGON ((140.11000 59.64525, 135.92698 69.211...  2022-09-07T04:38:00Z
# 1  POLYGON ((120.10182 59.68070, 109.90703 75.555...  2022-09-07T04:38:21Z
# 2  POLYGON ((94.85654 59.25999, 114.56779 67.6165...  2022-09-07T04:38:27Z
# 3  POLYGON ((79.38503 59.64414, 119.14482 70.2361...  2022-09-07T04:41:10Z
# 4  POLYGON ((59.44215 59.62811, 88.03016 70.11116...  2022-09-07T04:38:13Z
#
#                        updated datetime platform proj:epsg  \
# 0  2022-09-06T22:40:01.142000Z     None     aqua      None
# 1  2022-09-06T22:40:11.792000Z     None     aqua      None
# 2  2022-09-06T22:41:08.907000Z     None     aqua      None
# 3  2022-09-06T22:43:57.652000Z     None     aqua      None
# 4  2022-09-06T22:39:29.017000Z     None     aqua      None
#
#                                            proj:wkt2    proj:shape  \
# 0  PROJCS["unnamed",GEOGCS["Unknown datum based u...  [2400, 2400]
# ...

# %%
items
# Out:
# <div class="jp-RenderedHTMLCommon jp-RenderedHTML jp-mod-trusted jp-OutputArea-output">
#     <div style="
#         width: 24px;
#         height: 24px;
#         background-color: #E1E1E1;
#         border: 3px solid #9D9D9D;
#         border-radius: 5px;
#         position: absolute;">
#     </div>
#     <div>
#         <details style="margin-left: 48px;">
#             <summary style="margin-bottom: 20px;">
#                 <h3 style="margin-bottom: 0px; display: inline;">
#                     ItemCollection
#                 </h3>
#             </summary>
#             <table style="width: 100%; text-align: left;">
#
#             </table>
#
#
#                 <details>
#
#                         <i> Only the first 10 items shown </i>
#
#                     <summary style="margin-bottom: 10px; margin-top: 10px">
#                         <h4 style="margin-bottom: 0px; display: inline;">Items</h4>
#                     </summary>
#
#
#
# ...
